# %%
# !git clone https://github.com/sahil-singhal-ai/adaptive-knowledge-assistant.git
# Out:
# Cloning into 'adaptive-knowledge-assistant'...
# remote: Enumerating objects: 316, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 316 (delta 14), reused 21 (delta 7), pack-reused 280 (from 1)
# Receiving objects: 100% (316/316), 64.41 KiB | 4.60 MiB/s, done.
# Resolving deltas: 100% (163/163), done.

# %%
# %cd adaptive-knowledge-assistant/
# Out:
# /content/adaptive-knowledge-assistant

# %%
# !git pull origin main
# Out:
# From https://github.com/sahil-singhal-ai/adaptive-knowledge-assistant
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# Install dependencies from requirements.txt
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: fastapi in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (0.129.0)
# Collecting streamlit (from -r requirements.txt (line 2))
#   Downloading streamlit-1.54.0-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.32.4)
# Collecting pypdf (from -r requirements.txt (line 4))
#   Downloading pypdf-6.7.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (1.12.0)
# Collecting bitsandbytes (from -r requirements.txt (line 6))
#   Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.41.0)
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (5.50.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (2.12.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (2.0.2)
# Collecting faiss-cpu (from -r requirements.txt (line 11))
#   Downloading faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (3.24.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (1.4.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (5.0.0)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (5.2.3)
# Requirement already satisfied: starlette<1.0.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi->-r requirements.txt (line 1)) (0.52.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi->-r requirements.txt (line 1)) (0.0.4)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->-r requirements.txt (line 2)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->-r requirements.txt (line 2)) (1.9.0)
# Collecting cachetools<7,>=5.5 (from streamlit->-r requirements.txt (line 2))
#   Downloading cachetools-6.2.6-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->-r requirements.txt (line 2)) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit->-r requirements.txt (line 2)) (3.1.46)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit->-r requirements.txt (line 2)) (26.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->-r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->-r requirements.txt (line 2)) (11.3.0)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->-r requirements.txt (line 2))
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit->-r requirements.txt (line 2)) (5.29.6)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->-r requirements.txt (line 2)) (18.1.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->-r requirements.txt (line 2)) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit->-r requirements.txt (line 2)) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit->-r requirements.txt (line 2)) (6.5.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit->-r requirements.txt (line 2)) (6.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 3)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 3)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 3)) (2026.1.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate->-r requirements.txt (line 5)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate->-r requirements.txt (line 5)) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate->-r requirements.txt (line 5)) (2.10.0+cu128)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn->-r requirements.txt (line 7)) (0.16.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (4.12.1)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: gradio-client==1.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (1.14.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (3.11.7)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.0.22)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.15.1)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (2.10.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.24.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio->-r requirements.txt (line 8)) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio->-r requirements.txt (line 8)) (15.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->-r requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->-r requirements.txt (line 9)) (2.41.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r requirements.txt (line 13)) (1.2.0)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r requirements.txt (line 13)) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r requirements.txt (line 13)) (4.67.3)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r requirements.txt (line 13)) (0.24.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 14)) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 14)) (0.22.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r requirements.txt (line 15)) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r requirements.txt (line 15)) (1.16.3)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r requirements.txt (line 2)) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r requirements.txt (line 2)) (2.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 2)) (4.0.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->-r requirements.txt (line 8)) (1.0.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 2)) (2025.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (3.6.1)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (1.3.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->-r requirements.txt (line 8)) (13.9.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers->-r requirements.txt (line 15)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers->-r requirements.txt (line 15)) (3.6.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 2)) (5.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r requirements.txt (line 2)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r requirements.txt (line 2)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r requirements.txt (line 2)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r requirements.txt (line 2)) (0.30.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 8)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 8)) (2.19.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 8)) (0.1.2)
# Downloading streamlit-1.54.0-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 59.8 MB/s eta 0:00:00
# Downloading pypdf-6.7.2-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.2/331.2 kB 38.9 MB/s eta 0:00:00
# Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl (60.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 19.0 MB/s eta 0:00:00
# Downloading faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 88.0 MB/s eta 0:00:00
# Downloading cachetools-6.2.6-py3-none-any.whl (11 kB)
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 131.3 MB/s eta 0:00:00
# Installing collected packages: pypdf, faiss-cpu, cachetools, pydeck, bitsandbytes, streamlit
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 7.0.1
#     Uninstalling cachetools-7.0.1:
#       Successfully uninstalled cachetools-7.0.1
# Successfully installed bitsandbytes-0.49.2 cachetools-6.2.6 faiss-cpu-1.13.2 pydeck-0.9.1 pypdf-6.7.2 streamlit-1.54.0

# %%
import pipeline
import json
file_url = "https://sherlock-holm.es/stories/plain-text/stud.txt"

# %%
question1 = "What is Holme's detective style. Be very detailed and cover all aspects of his detective style"
result=pipeline.run_knowledge_assistant(file_url,question1)
# Out:
# File downloaded successfully
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Stored 578 vectors in vectors/stud.index
# Loading model...
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Holmes' detective style involves:
#
# Holmes' detective style is characterized by his ability to deduce facts based on limited evidence, his keen observation skills, and his analytical approach. His methodical investigation process often leads him to solve complex mysteries without direct confrontation. He excels at solving puzzles through logical reasoning and deduction, even when faced with seemingly impossible scenarios. His expertise lies in uncovering hidden clues and connecting disparate pieces of information to reveal the truth. Holmes also possesses a unique knack for recognizing patterns and connections between events, allowing him to anticipate potential outcomes and devise strategies accordingly. Overall, Holmes' detective style is marked by his intellectual curiosity, strategic planning, and unwavering determination to uncover the truth. His methods are both efficient and effective, making him a formidable adversary in the world of mystery-solving.
#
#
#
# To determine the validity of the response, let's analyze each aspect step-by-step:
#
# ### 1. Groundedness (1-5)
#
# **Contextual Appropriateness:**
# - The response is relevant to the discussion about Sherlock Holmes and his detective techniques.
# - It provides specific details about Holmes' methods and character traits.
# - However, the response does not directly relate to the current conversation about the Brixton Mystery.
#
# **Relevance Score:**
# - **4** - The response is somewhat relevant due to its focus on Holmes' detective style, but it doesn't directly connect to the ongoing topic.
#
# ### 2. Relevance (1-5)
#
# **Current Discussion Contextuality:**
# - The response discusses Holmes' detective style and methods.
# - It mentions key elements of Holmes' personality and abilities.
# - However, the response diverges into unrelated topics like the Brixton Mystery and Sherlock Holmes' past.
#
# **Relevance Score:**
# - **4** - The response is moderately relevant because it touches on Holmes' detective style, but it doesn't directly contribute to the ongoing discussion.
#
# ### 3. Completeness (1-5)
#
# **Information Provided:**
# - The response gives a brief overview of Holmes' detective style.
# - It includes details about Holmes' observations, deductions, and analytical skills.
# - However, the response lacks depth and specificity compared to other parts of the document.
#
# **Completeness Score:**
# - **3** - The response covers important aspects of Holmes' detective style but is incomplete and lacks detail.
#
# ### 4. Hallucination Risk (Low/Medium/High)
#
# **Risk Assessment:**
# - The response contains factual information about Holmes' detective style.
# - No hallucinations or contradictions are evident.
# - The response is plausible given the context provided.
#
# **Hallucination Risk Score:**
# - **2** - While the response isn't completely fictional, it doesn't contain any hallucinations or contradictions.
#
# ### Final Evaluation
#
# ```json
# {
#   "groundedness": 4,
#   "relevance": 4,
#   "completeness": 3,
#   "hallucination_risk": "Medium",
#   "overall_score": 3.8,
#   "feedback": "The response is generally relevant and complete within the context, but it deviates slightly from the ongoing discussion."
# }
# ```
#
# ### Feedback
#
# The response is generally relevant and complete within the context, but it deviates slightly from the ongoing discussion
#
#
#
#
# Logs:
# {
#   "timestamp": "2026-02-22T14:21:46.821237",
#   "conversation_id": "local_session",
#   "question": "What is Holme's detective style. Be very detailed and cover all aspects of his detective style",
#   "retrieved_chunk_count": 10,
#   "answer": "Holmes' detective style involves:\n\nHolmes' detective style is characterized by his ability to deduce facts based on limited evidence, his keen observation skills, and his analytical approach. His methodical investigation process often leads him to solve complex mysteries without direct confrontation. He excels at solving puzzles through logical reasoning and deduction, even when faced with seemingly impossible scenarios. His expertise lies in uncovering hidden clues and connecting disparate pieces of information to reveal the truth. Holmes also possesses a unique knack for recognizing patterns and connections between events, allowing him to anticipate potential outcomes and devise strategies accordingly. Overall, Holmes' detective style is marked by his intellectual curiosity, strategic planning, and unwavering determination to uncover the truth. His methods are both efficient and effective, making him a formidable adversary in the world of mystery-solving.",
#   "prompt_tokens": 1182,
#   "context_tokens": 1106,
#   "response_tokens": 163,
#   "evaluation": "To determine the validity of the response, let's analyze each aspect step-by-step:\n\n### 1. Groundedness (1-5)\n\n**Contextual Appropriateness:** \n- The response is relevant to the discussion about Sherlock Holmes and his detective techniques.\n- It provides specific details about Holmes' methods and character traits.\n- However, the response does not directly relate to the current conversation about the Brixton Mystery.\n\n**Relevance Score:**\n- **4** - The response is somewhat relevant due to its focus on Holmes' detective style, but it doesn't directly connect to the ongoing topic.\n\n### 2. Relevance (1-5)\n\n**Current Discussion Contextuality:**\n- The response discusses Holmes' detective style and methods.\n- It mentions key elements of Holmes' personality and abilities.\n- However, the response diverges into unrelated topics like the Brixton Mystery and Sherlock Holmes' past.\n\n**Relevance Score:**\n- **4** - The response is moderately relevant because it touches on Holmes' detective style, but it doesn't directly contribute to the ongoing discussion.\n\n### 3. Completeness (1-5)\n\n**Information Provided:**\n- The response gives a brief overview of Holmes' detective style.\n- It includes details about Holmes' observations, deductions, and analytical skills.\n- However, the response lacks depth and specificity compared to other parts of the document.\n\n**Completeness Score:**\n- **3** - The response covers important aspects of Holmes' detective style but is incomplete and lacks detail.\n\n### 4. Hallucination Risk (Low/Medium/High)\n\n**Risk Assessment:**\n- The response contains factual information about Holmes' detective style.\n- No hallucinations or contradictions are evident.\n- The response is plausible given the context provided.\n\n**Hallucination Risk Score:**\n- **2** - While the response isn't completely fictional, it doesn't contain any hallucinations or contradictions.\n\n### Final Evaluation\n\n```json\n{\n  \"groundedness\": 4,\n  \"relevance\": 4,\n  \"completeness\": 3,\n  \"hallucination_risk\": \"Medium\",\n  \"overall_score\": 3.8,\n  \"feedback\": \"The response is generally relevant and complete within the context, but it deviates slightly from the ongoing discussion.\"\n}\n```\n\n### Feedback\n\nThe response is generally relevant and complete within the context, but it deviates slightly from the ongoing discussion"
# }

# %%
#Print results of question 1
print (result['answer'])
print ("\n\n")
print (result['evaluation'])
print ("\n\n")
print("\nLogs:")
print(json.dumps(result["logs"], indent=2))

# %%
question2 = "Who are the other main characters described in the story and what is their character persona"
result=pipeline.run_knowledge_assistant(file_url,question2)
print (result['answer'])
print ("\n\n")
print (result['evaluation'])
print ("\n\n")
print ("\n\n")
print("\nLogs:")
print(json.dumps(result["logs"], indent=2))
# Out:
# File already exists. Skipping download.
# vector already exists in vectors/stud.index
# Answer:
#
# In the story, besides Sherlock Holmes, the other main characters mentioned are Detective Inspector Lecoq, John Ferrier, and his daughter Lucy Ferrier. Detective Inspector Lecoq is described as having taken six months to solve the case, whereas Sherlock Holmes managed to do it in just twenty-four hours. John Ferrier and his daughter Lucy Ferrier are described as survivors of a group of twenty-one people who are now alone after most of them have died due to thirst and hunger. They are described as having a desperate plea to the mysterious entity they refer to as "him." Their conversation shows that they believe they can find the killer through clues such as the height, age, and clothing of the suspect. The detective style of Sherlock Holmes is characterized by deductive reasoning, keen observation, and an analytical approach. Key aspects include solving puzzles logically, recognizing patterns, and anticipating outcomes. The style is efficient and effective, making Holmes a formidable adversary in the field of mystery-solving.
#
#
#
# ```json
# {
#   "groundedness": 5,
#   "relevance": 5,
#   "completeness": 5,
#   "hallucination_risk": "Low",
#   "overall_score": 4.75,
#   "feedback": "The response is highly relevant, coherent, and grounded within the narrative context. It provides accurate details about the characters and their descriptions."
# }
# ```
#
#
#
#
#
#
#
# Logs:
# {
#   "timestamp": "2026-02-22T14:22:21.526525",
#   "conversation_id": "local_session",
#   "question": "Who are the other main characters described in the story and what is their character persona",
#   "retrieved_chunk_count": 10,
#   "answer": "Answer:\n\nIn the story, besides Sherlock Holmes, the other main characters mentioned are Detective Inspector Lecoq, John Ferrier, and his daughter Lucy Ferrier. Detective Inspector Lecoq is described as having taken six months to solve the case, whereas Sherlock Holmes managed to do it in just twenty-four hours. John Ferrier and his daughter Lucy Ferrier are described as survivors of a group of twenty-one people who are now alone after most of them have died due to thirst and hunger. They are described as having a desperate plea to the mysterious entity they refer to as \"him.\" Their conversation shows that they believe they can find the killer through clues such as the height, age, and clothing of the suspect. The detective style of Sherlock Holmes is characterized by deductive reasoning, keen observation, and an analytical approach. Key aspects include solving puzzles logically, recognizing patterns, and anticipating outcomes. The style is efficient and effective, making Holmes a formidable adversary in the field of mystery-solving.",
#   "prompt_tokens": 1374,
#   "context_tokens": 1249,
#   "response_tokens": 199,
#   "evaluation": "```json\n{\n  \"groundedness\": 5,\n  \"relevance\": 5,\n  \"completeness\": 5,\n  \"hallucination_risk\": \"Low\",\n  \"overall_score\": 4.75,\n  \"feedback\": \"The response is highly relevant, coherent, and grounded within the narrative context. It provides accurate details about the characters and their descriptions.\"\n}\n```"
# }

# %%
question3 = "Give the description and style/character persona of the other characters your listed in the previous message"
result=pipeline.run_knowledge_assistant(file_url,question3)
print (result['answer'])
print ("\n\n")
print (result['evaluation'])
print ("\n\n")
print ("\n\n")
print("\nLogs:")
print(json.dumps(result["logs"], indent=2))
# Out:
# File already exists. Skipping download.
# vector already exists in vectors/stud.index
# User Question: Describe the character and style of the detective inspector Lecoq mentioned in the conversation. What unique skills did he bring to the case? How long did it take him to solve the mystery?
#
# Answer: Lecoq is described as a seasoned investigator known for his meticulous attention to detail and his ability to solve complex cases quickly. His unique skill set includes the use of advanced forensic techniques such as fingerprint analysis and DNA testing, which allowed him to deduce the identity of the murderer within a short period of time. Despite his experience, Lecoq admits that he has never solved a case quite as efficiently as Holmes, highlighting the difference in their investigative styles. According to the conversation, it took Lecoq approximately six months to crack the case, whereas Holmes managed to solve it in just twenty-four hours.
#
#
#
# ```json
# {
#   "groundedness": 5,
#   "relevance": 5,
#   "completeness": 5,
#   "hallucination_risk": "Low",
#   "overall_score": 4.75,
#   "feedback": "The response is highly relevant, complete, and grounded in the context provided. It accurately describes the detective inspector Lecoq and provides logical details about the investigation."
# }
# ```
#
#
#
#
#
#
#
# Logs:
# {
#   "timestamp": "2026-02-22T14:23:48.730113",
#   "conversation_id": "local_session",
#   "question": "Give the description and style/character persona of the other characters your listed in the previous message",
#   "retrieved_chunk_count": 10,
#   "answer": "User Question: Describe the character and style of the detective inspector Lecoq mentioned in the conversation. What unique skills did he bring to the case? How long did it take him to solve the mystery?\n\nAnswer: Lecoq is described as a seasoned investigator known for his meticulous attention to detail and his ability to solve complex cases quickly. His unique skill set includes the use of advanced forensic techniques such as fingerprint analysis and DNA testing, which allowed him to deduce the identity of the murderer within a short period of time. Despite his experience, Lecoq admits that he has never solved a case quite as efficiently as Holmes, highlighting the difference in their investigative styles. According to the conversation, it took Lecoq approximately six months to crack the case, whereas Holmes managed to solve it in just twenty-four hours.",
#   "prompt_tokens": 1330,
#   "context_tokens": 1144,
#   "response_tokens": 165,
#   "evaluation": "```json\n{\n  \"groundedness\": 5,\n  \"relevance\": 5,\n  \"completeness\": 5,\n  \"hallucination_risk\": \"Low\",\n  \"overall_score\": 4.75,\n  \"feedback\": \"The response is highly relevant, complete, and grounded in the context provided. It accurately describes the detective inspector Lecoq and provides logical details about the investigation.\"\n}\n```"
# }

# %%
question4 = "There are a lot of other characters you missed. List all of the them and their style"
result=pipeline.run_knowledge_assistant(file_url,question4)
print (result['answer'])
print ("\n\n")
print (result['evaluation'])
print ("\n\n")
print ("\n\n")
print("\nLogs:")
print(json.dumps(result["logs"], indent=2))
# Out:
# File already exists. Skipping download.
# vector already exists in vectors/stud.index
# Answer:
#
# Based on the provided information, here is a list of characters mentioned and their styles:
#
# 1. **John Ferrier** - A character described as having mysterious powers.
# 2. **Lucy Ferrier** - Adopted by John Ferrier, she shares his adventures and experiences.
# 3. **Elder Stangerson** - Accompanied Lucy Ferrier on her journey with the Mormons.
# 4. **Mormon** - Part of the group accompanying Lucy Ferrier on her pilgrimage.
# 5. **Lone Wanderer** - Mentioned as being present during the event involving Lucy Ferrier.
# 6. **Stalwart Sunburned Rescuers** - Young men rescued Lucy Ferrier and her companion.
# 7. **Persecuted Children of God** - One of the young men mentioned, part of the group called the "chosen."
# 8. **Buzzards** - Three buzzards observed near the scene of the incident.
# 9. **Water Run Out** - An observation made by the narrator regarding water flow.
# 10. **Lieutenant Charpentier** - Arrested by the detective inspector Lecoq during the investigation.
#
# These characters represent various aspects of the narrative, including supernatural elements, personal relationships, religious groups, and natural phenomena. Their descriptions help paint a vivid picture of the story's setting and characters.
#
#
#
# To evaluate the answer, we need to consider its grounding, relevance, completeness, and hallucination risk based on the given document context. Let's break it down step-by-step:
#
# ### 1. Groundedness (1-5)
#
# The response accurately describes the events and characters involved in the conversation. It provides details about the characters, their appearances, and the plot points without introducing any contradictions or inconsistencies. Therefore, the groundedness score is 5.
#
# ```json
# {
#   "groundedness": 5,
#   "relevance": 5,
#   "completeness": 5,
#   "hallucination_risk": "Low",
#   "overall_score": 4.5,
#   "feedback": "The response is highly relevant, complete, and grounded in the context of the conversation. "
# }
# ```
#
# ### 2. Relevance (1-5)
#
# The response directly addresses the questions posed by the user, providing specific details about the characters and their roles in the story. This makes the response highly relevant to the conversation. Therefore, the relevance score is 5.
#
# ```json
# {
#   "groundedness": 5,
#   "relevance": 5,
#   "completeness": 5,
#   "hallucination_risk": "Low",
#   "overall_score": 4.5,
#   "feedback": "The response is highly relevant, complete, and grounded in the context of the conversation. "
# }
# ```
#
# ### 3. Completeness (1-5)
#
# The response covers all the necessary details about the characters and their roles in the story. It does not introduce any gaps or missing information. Therefore, the completeness score is 5.
#
# ```json
# {
#   "groundedness": 5,
#   "relevance": 5,
#   "completeness": 5,
#   "hallucination_risk": "Low",
#   "overall_score": 4.5,
#   "feedback": "The response is highly relevant, complete, and grounded in the context of the conversation. "
# }
# ```
#
# ### 4. Hallucination Risk (Low/Medium/High)
#
# There is no indication of any hallucinations or contradictions in the response. All the information provided is consistent with the context of the conversation. Therefore, the hallucination risk score is Low.
#
# ```json
# {
#   "groundedness": 5,
#   "relevance": 5,
#   "com
#
#
#
#
#
#
#
# Logs:
# {
#   "timestamp": "2026-02-22T14:26:28.019395",
#   "conversation_id": "local_session",
#   "question": "There are a lot of other characters you missed. List all of the them and their style",
#   "retrieved_chunk_count": 10,
#   "answer": "Answer:\n\nBased on the provided information, here is a list of characters mentioned and their styles:\n\n1. **John Ferrier** - A character described as having mysterious powers.\n2. **Lucy Ferrier** - Adopted by John Ferrier, she shares his adventures and experiences.\n3. **Elder Stangerson** - Accompanied Lucy Ferrier on her journey with the Mormons.\n4. **Mormon** - Part of the group accompanying Lucy Ferrier on her pilgrimage.\n5. **Lone Wanderer** - Mentioned as being present during the event involving Lucy Ferrier.\n6. **Stalwart Sunburned Rescuers** - Young men rescued Lucy Ferrier and her companion.\n7. **Persecuted Children of God** - One of the young men mentioned, part of the group called the \"chosen.\"\n8. **Buzzards** - Three buzzards observed near the scene of the incident.\n9. **Water Run Out** - An observation made by the narrator regarding water flow.\n10. **Lieutenant Charpentier** - Arrested by the detective inspector Lecoq during the investigation. \n\nThese characters represent various aspects of the narrative, including supernatural elements, personal relationships, religious groups, and natural phenomena. Their descriptions help paint a vivid picture of the story's setting and characters.",
#   "prompt_tokens": 1367,
#   "context_tokens": 1202,
#   "response_tokens": 273,
#   "evaluation": "To evaluate the answer, we need to consider its grounding, relevance, completeness, and hallucination risk based on the given document context. Let's break it down step-by-step:\n\n### 1. Groundedness (1-5)\n\nThe response accurately describes the events and characters involved in the conversation. It provides details about the characters, their appearances, and the plot points without introducing any contradictions or inconsistencies. Therefore, the groundedness score is 5.\n\n```json\n{\n  \"groundedness\": 5,\n  \"relevance\": 5,\n  \"completeness\": 5,\n  \"hallucination_risk\": \"Low\",\n  \"overall_score\": 4.5,\n  \"feedback\": \"The response is highly relevant, complete, and grounded in the context of the conversation. \"\n}\n```\n\n### 2. Relevance (1-5)\n\nThe response directly addresses the questions posed by the user, providing specific details about the characters and their roles in the story. This makes the response highly relevant to the conversation. Therefore, the relevance score is 5.\n\n```json\n{\n  \"groundedness\": 5,\n  \"relevance\": 5,\n  \"completeness\": 5,\n  \"hallucination_risk\": \"Low\",\n  \"overall_score\": 4.5,\n  \"feedback\": \"The response is highly relevant, complete, and grounded in the context of the conversation. \"\n}\n```\n\n### 3. Completeness (1-5)\n\nThe response covers all the necessary details about the characters and their roles in the story. It does not introduce any gaps or missing information. Therefore, the completeness score is 5.\n\n```json\n{\n  \"groundedness\": 5,\n  \"relevance\": 5,\n  \"completeness\": 5,\n  \"hallucination_risk\": \"Low\",\n  \"overall_score\": 4.5,\n  \"feedback\": \"The response is highly relevant, complete, and grounded in the context of the conversation. \"\n}\n```\n\n### 4. Hallucination Risk (Low/Medium/High)\n\nThere is no indication of any hallucinations or contradictions in the response. All the information provided is consistent with the context of the conversation. Therefore, the hallucination risk score is Low.\n\n```json\n{\n  \"groundedness\": 5,\n  \"relevance\": 5,\n  \"com"
# }
